# %%
# This code implements a glcm texture analysis.
# It loops through a folder of images, calculates the glcm for each image, and saves the results
# to series of files.

from skimage.io import imread
# from skimage.io import imshow
from skimage.feature import graycomatrix, graycoprops
import os
import numpy as np
import matplotlib.pyplot as plt

root_path = "/home/shannon/local/Source/Python/bm_study/unet"
source_path = "data/images"
dest_path = "data/glcm"
# SOURCE_PATH = '/home/shannon/local/Source/Python/bm_study/images/originals/resized/'
# DEST_PATH = '/home/shannon/local/Source/Python/bm_study/images/originals/resized/glcm/'

window_size = 7

# This code implements the code on this webpage:
# https://scikit-image.org/docs/stable/auto_examples/features_detection/plot_glcm.html

def glcm_image(img, window = 7):
    """TODO: allow different window sizes by parameterizing 3, 4. Also should
    parameterize direction vector [1] [0]"""
    # texture = np.zeros_like(img)
    textures_size = (5, img.shape[0], img.shape[1])
    textures = np.zeros(textures_size)

    # quadratic looping in python w/o vectorized routine, yuck!
    for i in range(img.shape[0] ):  
        for j in range(img.shape[1] ):  
          
            # don't calculate at edges
            if (i < window // 2 ) or \
               (i > (img.shape[0])) or \
               (j < window // 2) or \
               (j > (img.shape[0] - window // 2 - 1)):          
                continue  
        
            # calculate glcm matrix for 7 x 7 window, use dissimilarity (can swap in
            # contrast, etc.)
            glcm_window = img[i-window // 2: i + window // 2 + 1, j - window // 2 : j + window // 2 + 1]  
            glcm = graycomatrix(glcm_window, [1], [0],  symmetric = True, normed = True )   
            textures[0, i, j] = graycoprops(glcm, 'dissimilarity').item(0)
            textures[1, i, j] = graycoprops(glcm, 'contrast').item(0)
            textures[2, i, j] = graycoprops(glcm, 'homogeneity').item(0)
            textures[3, i, j] = graycoprops(glcm, 'energy').item(0)
            textures[4, i, j] = graycoprops(glcm, 'correlation').item(0)

    return textures

# Get a list of all PNG files in the TRAIN_PATH directory
png_files = [f for f in os.listdir(os.path.join(root_path, source_path)) if f.endswith('.png') and not 'glcm' in f]

# Loop through the PNG files
for file in png_files:
    # Load the image
    img = imread(os.path.join(root_path, source_path, file))
    
    # Calculate the glcm_image
    result = glcm_image(img, window=window_size)    
    
    # Get the filename without extension
    filename = os.path.splitext(file)[0]
    
    # Add _glcm to the end of the filename
    new_filename = os.path.join(root_path, dest_path, filename + '_glcm.png')
    
    # Save the result to the new filename
    plt.imsave(os.path.join(root_path, dest_path, filename + '_glcm_diss.png'), result[0, :, :], cmap='gray')
    plt.imsave(os.path.join(root_path, dest_path, filename + '_glcm_cont.png'), result[1, :, :], cmap='gray')
    plt.imsave(os.path.join(root_path, dest_path, filename + '_glcm_homogen.png'), result[2, :, :], cmap='gray')
    plt.imsave(os.path.join(root_path, dest_path, filename + '_glcm_energy.png'), result[3, :, :], cmap='gray')
    plt.imsave(os.path.join(root_path, dest_path, filename + '_glcm_corr.png'), result[4, :, :], cmap='gray')
    
    print(f'Converted {filename} to GLCM layers')
# Out:
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B5_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J10_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J12_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E7_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J11_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H9_BD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F6_CD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I10_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E5_AB_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H10_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F3_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D15_4_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I1_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_F17_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F2_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_A6_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H9_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I7_CD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E5_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I11_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I2_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J11_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C3_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I12_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H11_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H10_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H8_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I8_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G7_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B6_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I9_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A8_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H8_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/K4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I1_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H6_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E3_2_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F9_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E4_3_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N9_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E8_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F9_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G7_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_F5_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G11_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F7_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I9_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A8_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H11_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F9_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B8_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C3_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E17_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A3_AB_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B3_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B9_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J10_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I7_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D14_3_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B4_A,B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_C7_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/L5_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E12_2_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E13_4_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E2_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I8_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B9_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J9_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I11_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H3_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/K1_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F4_CD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D8_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E8_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F8_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E16_4_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G7_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H9_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I5_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E2_4_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I1_CD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G9_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J3_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I10_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G5_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E16_2_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H9_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B3_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J1_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D15_2_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H6_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G5_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B6_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C9_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E1_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D17_3_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D13_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I10_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F9_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I7_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A9_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G3_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G10_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I10_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H6_AB_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E13_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C2_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F5_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I12_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D7_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F3_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/N5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C6_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G6_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B3_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_D3_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/K17_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_B5_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J11_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E7_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J12_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D4_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G2_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E1_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H7_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J3_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/1899-288-512_RMand_Ext_E5_1_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H8_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I5_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I17_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C6_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E2_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J10_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/J10_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B6_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A6_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G4_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B4_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I8_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/O3_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A4_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E7_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/A6_CD_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E6_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F8_C_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F2_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/G8_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/E2_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H7_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I6_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F7_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/B5_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/C5_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/D7_D_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/H10_A_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/I8_B_glcm.png
# Saved /home/shannon/local/Source/Python/bm_study/images/originals/resized/F3_A_glcm.png
